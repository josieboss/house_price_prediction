# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Amberlynnyandow/dsc-1-final-project-online-ds-ft-021119/master/kc_house_data.csv")

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
df.shape
# Out:
# (21597, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.isna()
# Out:
#           id   date  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      False  False  False     False      False        False     False
# 1      False  False  False     False      False        False     False
# 2      False  False  False     False      False        False     False
# 3      False  False  False     False      False        False     False
# 4      False  False  False     False      False        False     False
# ...      ...    ...    ...       ...        ...          ...       ...
# 21592  False  False  False     False      False        False     False
# 21593  False  False  False     False      False        False     False
# 21594  False  False  False     False      False        False     False
# 21595  False  False  False     False      False        False     False
# 21596  False  False  False     False      False        False     False
#
#        floors  waterfront   view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
df.isna().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
df['date']
# Out:
# 0        10/13/2014
# 1         12/9/2014
# 2         2/25/2015
# 3         12/9/2014
# 4         2/18/2015
#             ...
# 21592     5/21/2014
# 21593     2/23/2015
# 21594     6/23/2014
# 21595     1/16/2015
# 21596    10/15/2014
# Name: date, Length: 21597, dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])
df['day'] = df['date'].dt.day
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year

# %%
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  yr_built  yr_renovated  zipcode  \
# 0      5650     1.0         NaN   0.0  ...      1955           0.0    98178
# 1      7242     2.0         0.0   0.0  ...      1951        1991.0    98125
# 2     10000     1.0         0.0   0.0  ...      1933           NaN    98028
# 3      5000     1.0         0.0   0.0  ...      1965           0.0    98136
# 4      8080     1.0         0.0   0.0  ...      1987           0.0    98074
#
#        lat     long  sqft_living15  sqft_lot15  day  month  year
# ...

# %%
df = df.drop('month', axis=1)
df = df.drop('year', axis=1)
df = df.drop('day', axis=1)

# %%
df['date'] = pd.to_datetime(df['date'])
df.insert(2, 'day', df['date'].dt.day)
df.insert(3, 'month', df['date'].dt.month)
df.insert(4, 'year', df['date'].dt.year)

# %%
df.head()
# Out:
#            id       date  day  month  year     price  bedrooms  bathrooms  \
# 0  7129300520 2014-10-13   13     10  2014  221900.0         3       1.00
# 1  6414100192 2014-12-09    9     12  2014  538000.0         3       2.25
# 2  5631500400 2015-02-25   25      2  2015  180000.0         2       1.00
# 3  2487200875 2014-12-09    9     12  2014  604000.0         4       3.00
# 4  1954400510 2015-02-18   18      2  2015  510000.0         3       2.00
#
#    sqft_living  sqft_lot  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0         1180      5650  ...      7        1180            0.0      1955
# 1         2570      7242  ...      7        2170          400.0      1951
# 2          770     10000  ...      6         770            0.0      1933
# 3         1960      5000  ...      7        1050          910.0      1965
# 4         1680      8080  ...      8        1680            0.0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
df['condition'].unique()
# Out:
# array([3, 5, 4, 1, 2], dtype=int64)

# %%
def replace_val(x):
    curr = {1:'Bad', 2: 'Not_Good', 3: 'Good', 4: 'Very_Good', 5: 'Excellent'}
    return curr[x]

# %%
replace_val(5)
# Out:
# 'Excellent'

# %%
df['condition'] = df['condition'].apply(replace_val)

# %%
df.head()
# Out:
#            id       date  day  month  year     price  bedrooms  bathrooms  \
# 0  7129300520 2014-10-13   13     10  2014  221900.0         3       1.00
# 1  6414100192 2014-12-09    9     12  2014  538000.0         3       2.25
# 2  5631500400 2015-02-25   25      2  2015  180000.0         2       1.00
# 3  2487200875 2014-12-09    9     12  2014  604000.0         4       3.00
# 4  1954400510 2015-02-18   18      2  2015  510000.0         3       2.00
#
#    sqft_living  sqft_lot  ...  grade  sqft_above  sqft_basement yr_built  \
# 0         1180      5650  ...      7        1180            0.0     1955
# 1         2570      7242  ...      7        2170          400.0     1951
# 2          770     10000  ...      6         770            0.0     1933
# 3         1960      5000  ...      7        1050          910.0     1965
# 4         1680      8080  ...      8        1680            0.0     1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
pd.set_option('display.max_columns',100)

# %%
df.head()
# Out:
#            id       date  day  month  year     price  bedrooms  bathrooms  \
# 0  7129300520 2014-10-13   13     10  2014  221900.0         3       1.00
# 1  6414100192 2014-12-09    9     12  2014  538000.0         3       2.25
# 2  5631500400 2015-02-25   25      2  2015  180000.0         2       1.00
# 3  2487200875 2014-12-09    9     12  2014  604000.0         4       3.00
# 4  1954400510 2015-02-18   18      2  2015  510000.0         3       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 0         1180      5650     1.0         NaN   0.0       Good      7
# 1         2570      7242     2.0         0.0   0.0       Good      7
# 2          770     10000     1.0         0.0   0.0       Good      6
# 3         1960      5000     1.0         0.0   0.0  Excellent      7
# 4         1680      8080     1.0         0.0   0.0       Good      8
#
#    sqft_above sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# ...

# %%
df['condition'].nunique()
# Out:
# 5

# %%
df['condition'].value_counts()
# Out:
# Good         14020
# Very_Good     5677
# Excellent     1701
# Not_Good       170
# Bad             29
# Name: condition, dtype: int64

# %%
df['condition'].value_counts().keys()
# Out:
# Index(['Good', 'Very_Good', 'Excellent', 'Not_Good', 'Bad'], dtype='object')

# %%
val = []
for key in df['condition'].value_counts().keys():
    val.append(df['condition'].value_counts()[key])

# %%
val
# Out:
# [14020, 5677, 1701, 170, 29]

# %%
import matplotlib.pyplot as plt

# %%
courses = list(df['condition'].value_counts().keys())
values = val

fig = plt.figure(figsize = (10,5))
plt.bar(courses, values, color = 'purple', width = 0.4)

plt.xlabel('House conditions')
plt.ylabel('count')
plt.title('House conditions distributions')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['waterfront'].value_counts()
# Out:
# 0.0    19075
# 1.0      146
# Name: waterfront, dtype: int64

# %%
df['sqft_basement'].value_counts()
# Out:
# 0.0       12826
# ?           454
# 600.0       217
# 500.0       209
# 700.0       208
#           ...
# 1920.0        1
# 3480.0        1
# 2730.0        1
# 2720.0        1
# 248.0         1
# Name: sqft_basement, Length: 304, dtype: int64

# %%
df['yr_renovated'].value_counts()
# Out:
# 0.0       17011
# 2014.0       73
# 2013.0       31
# 2003.0       31
# 2007.0       30
#           ...
# 1951.0        1
# 1953.0        1
# 1946.0        1
# 1976.0        1
# 1948.0        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df['view'].value_counts()
# Out:
# 0.0    19422
# 2.0      957
# 3.0      508
# 1.0      330
# 4.0      317
# Name: view, dtype: int64

# %%
# Replace all missing values with the mode in each 
df = df.fillna({'yr_renovated': df['yr_renovated'].mean(), 'view': 0, 'waterfront': 0})

# %%
df.isna().sum()
# Out:
# id               0
# date             0
# day              0
# month            0
# year             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df['waterfront'].unique()
# Out:
# array([0., 1.])

# %%
df['sqft_basement'].nunique()
# Out:
# 304

# %%
df.describe()
# Out:
#                  id           day         month          year         price  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  2.159700e+04
# mean   4.580474e+09     15.687457      6.573969   2014.322962  5.402966e+05
# std    2.876736e+09      8.634890      3.115061      0.467619  3.673681e+05
# min    1.000102e+06      1.000000      1.000000   2014.000000  7.800000e+04
# 25%    2.123049e+09      8.000000      4.000000   2014.000000  3.220000e+05
# 50%    3.904930e+09     16.000000      6.000000   2014.000000  4.500000e+05
# 75%    7.308900e+09     23.000000      9.000000   2015.000000  6.450000e+05
# max    9.900000e+09     31.000000     12.000000   2015.000000  7.700000e+06
#
#            bedrooms     bathrooms   sqft_living      sqft_lot        floors  \
# count  21597.000000  21597.000000  21597.000000  2.159700e+04  21597.000000
# mean       3.373200      2.115826   2080.321850  1.509941e+04      1.494096
# ...

# %%
df.loc[df['bedrooms'] ==33]
# Out:
#                id       date  day  month  year     price  bedrooms  bathrooms  \
# 15856  2402100895 2014-06-25   25      6  2014  640000.0        33       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 15856         1620      6000     1.0         0.0   0.0  Excellent      7
#
#        sqft_above sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 15856        1040         580.0      1947           0.0    98103  47.6878
#
#           long  sqft_living15  sqft_lot15
# 15856 -122.331           1330        4700

# %%
#To replace the outlier 33 with 3 
df['bedrooms'] = df['bedrooms'].replace(33,3)

# %%
df.describe()
# Out:
#                  id           day         month          year         price  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  2.159700e+04
# mean   4.580474e+09     15.687457      6.573969   2014.322962  5.402966e+05
# std    2.876736e+09      8.634890      3.115061      0.467619  3.673681e+05
# min    1.000102e+06      1.000000      1.000000   2014.000000  7.800000e+04
# 25%    2.123049e+09      8.000000      4.000000   2014.000000  3.220000e+05
# 50%    3.904930e+09     16.000000      6.000000   2014.000000  4.500000e+05
# 75%    7.308900e+09     23.000000      9.000000   2015.000000  6.450000e+05
# max    9.900000e+09     31.000000     12.000000   2015.000000  7.700000e+06
#
#            bedrooms     bathrooms   sqft_living      sqft_lot        floors  \
# count  21597.000000  21597.000000  21597.000000  2.159700e+04  21597.000000
# mean       3.371811      2.115826   2080.321850  1.509941e+04      1.494096
# ...

# %%
df.loc[df['id'] == 2402100895]
# Out:
#                id       date  day  month  year     price  bedrooms  bathrooms  \
# 15856  2402100895 2014-06-25   25      6  2014  640000.0         3       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 15856         1620      6000     1.0         0.0   0.0  Excellent      7
#
#        sqft_above sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 15856        1040         580.0      1947           0.0    98103  47.6878
#
#           long  sqft_living15  sqft_lot15
# 15856 -122.331           1330        4700

# %%
import matplotlib.ticker as ticker

# %%
plt.bar(df['yr_built'], df['price'])

plt.xlabel('Year Built')
plt.ylabel('Price')
plt.title('Price by Year Built')

formatter = ticker.FormatStrFormatter('$%.0f')
plt.gca().yaxis.set_major_formatter(formatter)

plt.xticks(rotation=90)

plt.show()

# %%
df.loc[df['price'] >= 500000].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9203 entries, 1 to 21590
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             9203 non-null   int64
#  1   date           9203 non-null   datetime64[ns]
#  2   day            9203 non-null   int64
#  3   month          9203 non-null   int64
#  4   year           9203 non-null   int64
#  5   price          9203 non-null   float64
#  6   bedrooms       9203 non-null   int64
#  7   bathrooms      9203 non-null   float64
#  8   sqft_living    9203 non-null   int64
#  9   sqft_lot       9203 non-null   int64
#  10  floors         9203 non-null   float64
#  11  waterfront     9203 non-null   float64
#  12  view           9203 non-null   float64
#  13  condition      9203 non-null   object
#  14  grade          9203 non-null   int64
#  15  sqft_above     9203 non-null   int64
#  16  sqft_basement  9203 non-null   object
# ...

# %%
pd.set_option('display.max_columns', 100)

# %%
df.head()
# Out:
#            id       date  day  month  year     price  bedrooms  bathrooms  \
# 0  7129300520 2014-10-13   13     10  2014  221900.0         3       1.00
# 1  6414100192 2014-12-09    9     12  2014  538000.0         3       2.25
# 2  5631500400 2015-02-25   25      2  2015  180000.0         2       1.00
# 3  2487200875 2014-12-09    9     12  2014  604000.0         4       3.00
# 4  1954400510 2015-02-18   18      2  2015  510000.0         3       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 0         1180      5650     1.0         0.0   0.0       Good      7
# 1         2570      7242     2.0         0.0   0.0       Good      7
# 2          770     10000     1.0         0.0   0.0       Good      6
# 3         1960      5000     1.0         0.0   0.0  Excellent      7
# 4         1680      8080     1.0         0.0   0.0       Good      8
#
#    sqft_above sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# ...

# %%
def replace_val(x):
    curr = {'Bad': 1, 'Not_Good': 2, 'Good': 3, 'Very_Good': 4, 'Excellent': 5}
    return curr.get(x, 0)

# %%
df['condition'] = df['condition'].apply(replace_val)

# %%
df.head()
# Out:
#            id       date  day  month  year     price  bedrooms  bathrooms  \
# 0  7129300520 2014-10-13   13     10  2014  221900.0         3       1.00
# 1  6414100192 2014-12-09    9     12  2014  538000.0         3       2.25
# 2  5631500400 2015-02-25   25      2  2015  180000.0         2       1.00
# 3  2487200875 2014-12-09    9     12  2014  604000.0         4       3.00
# 4  1954400510 2015-02-18   18      2  2015  510000.0         3       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 0         1180      5650     1.0         0.0   0.0          3      7
# 1         2570      7242     2.0         0.0   0.0          3      7
# 2          770     10000     1.0         0.0   0.0          3      6
# 3         1960      5000     1.0         0.0   0.0          5      7
# 4         1680      8080     1.0         0.0   0.0          3      8
#
#    sqft_above sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# ...

# %%
df.isna().sum()
# Out:
# id               0
# date             0
# day              0
# month            0
# year             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.drop(['zipcode', 'lat', 'long'], inplace=True, axis=1)
df_r = df.loc[df['sqft_basement'] == '?']
df.drop(df_r.index, axis=0, inplace=True, errors = 'ignore')

# %%
x, y = df.iloc[:, 6:].values, df.iloc[:, 5].values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
x_train.shape, y_train.shape
# Out:
# ((14800, 15), (14800,))

# %%
from sklearn.ensemble import RandomForestClassifier as RFC

# %%
rfc = RFC(n_estimators=5, random_state=1)

# %%
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=5, random_state=1)
